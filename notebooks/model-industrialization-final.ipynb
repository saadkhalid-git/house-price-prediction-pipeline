# %% [markdown]
# ## Envoirnment Intialization

# %%
import sys
import pandas as pd
from os.path import dirname, abspath

# Enable autoreloading of modules
# %load_ext autoreload
# %autoreload 2

# Path appending
d = dirname(dirname(abspath('__file__')))
sys.path.append(d)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Setup package

# %%
import house_prices_prediction_pipeline as house_price_package

house_price_package.setup(
    features=['price', 'area', 'bedrooms', 'bathrooms', 'stories',
            'mainroad', 'guestroom', 'basement', 'hotwaterheating',
            'airconditioning', 'parking', 'prefarea',
            'furnishingstatus'],
    continuous_features=['area', 'bedrooms'],
    categorical_features=['mainroad', 'furnishingstatus'],
    target_feature='price',
    output_dir='../models/'
)

# %%
import pandas as pd
from house_prices_prediction_pipeline.train import build_model


training_data_df = pd.read_csv('../data/train.csv')
model_performance_dict = build_model(training_data_df)
print(model_performance_dict)
# Out:
# {'rmse': '1753370.2062800084', 'rmsle': '0.33'}

# %%
import pandas as pd
from house_prices_prediction_pipeline.inference import make_predictions

user_data_df = pd.read_csv('../data/test.csv')
predictions = make_predictions(user_data_df)
predictions
# Out:
# /opt/homebrew/Caskroom/miniconda/base/envs/data-science/lib/python3.9/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
# /opt/homebrew/Caskroom/miniconda/base/envs/data-science/lib/python3.9/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but OneHotEncoder was fitted without feature names
#   warnings.warn(
# array([4564123.37691637, 5738986.9994274 , 3861664.89724335,
#        4851228.60443249, 4887678.94579155, 4915377.45962843,
#        6416011.51452363, 5900703.89855333, 2336977.08077017,
#        3721144.69442997, 6718913.21734049, 3313810.40364439,
#        2497854.19326828, 3470191.53640675, 3993685.66927466,
#        3135499.2168678 , 3177937.16912637, 4674061.79088126,
#        4623787.6932256 , 4518579.77327731, 4345604.35286428,
#        5462896.79257635, 3218289.61809864, 3936708.35859825,
#        5940500.72030513, 6513625.43357966, 3030934.81416854,
# ...
